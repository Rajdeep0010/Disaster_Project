# %% [markdown]
# # ➡️ What Comes Next — Phase 3: Data Cleaning
# ```
# 1. Filter dataset to Start Year >= 1990
# 2. Handle near duplicates using location-based rules
# 3. Build colonial name mapping → extract Primary_State from Location
# 4. Combine date columns → create Start_Date and End_Date
# 5. Engineer Duration = End_Date − Start_Date (days)
# 6. Engineer Season from Start Month
# 7. Apply log1p transformation to Total Deaths, Total Affected, Total Damage
# 8. Encode categorical features for model input
# 9. Save cleaned dataset as emdat_india_cleaned.csv
